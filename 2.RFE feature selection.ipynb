# %%
import pandas as pd

# %%
heart_df = pd.read_csv('heart_disease.csv')
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    int64
#  1   sex       297 non-null    int64
#  2   cp        297 non-null    int64
#  3   trestbps  297 non-null    int64
#  4   chol      297 non-null    int64
#  5   fbs       297 non-null    int64
#  6   restecg   297 non-null    int64
#  7   thalach   297 non-null    int64
#  8   exang     297 non-null    int64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    int64
#  11  ca        297 non-null    float64
#  12  thal      297 non-null    float64
#  13  num       297 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 32.6 KB

# %%
X_feature = heart_df.drop('num', axis=1)
y_target = heart_df['num']

# %% [markdown]
# # *Recursive Feature Elimination (RFE)*

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

# %%
RF_mdl = RandomForestClassifier(random_state=1)
select = RFE(RF_mdl, n_features_to_select=8)  # RFE with 8 features selected
select.fit(X_feature, y_target)
selected_features = X_feature.columns[select.support_]
print("Selected eight features with RFE:", selected_features.tolist())
# Out:
# Selected eight features with RFE: ['age', 'cp', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca', 'thal']

# %%
X_rfe_chosen = X_feature[selected_features]
X_rfe_chosen
# Out:
#      age  cp  trestbps  chol  thalach  oldpeak   ca  thal
# 0     63   1       145   233      150      2.3  0.0   6.0
# 1     67   4       160   286      108      1.5  3.0   3.0
# 2     67   4       120   229      129      2.6  2.0   7.0
# 3     37   3       130   250      187      3.5  0.0   3.0
# 4     41   2       130   204      172      1.4  0.0   3.0
# ..   ...  ..       ...   ...      ...      ...  ...   ...
# 292   57   4       140   241      123      0.2  0.0   7.0
# 293   45   1       110   264      132      1.2  0.0   7.0
# 294   68   4       144   193      141      3.4  2.0   7.0
# 295   57   4       130   131      115      1.2  1.0   7.0
# 296   57   2       130   236      174      0.0  1.0   3.0
#
# [297 rows x 8 columns]
